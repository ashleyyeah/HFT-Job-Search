# %%
import csv
import pandas as pd
import numpy as np
import us

# %%
df = pd.read_csv("PERM_Disclosure_Data_FY2021.csv", low_memory=False)
df
# Out:
#           CASE_NUMBER SCHD_A_SHEEPHERDER                       EMPLOYER_NAME  \
# 0       A-19178-24147                  N                       Ennovaco Corp
# 1       A-19198-32049                  N             CAPGEMINI AMERICA, INC.
# 2       A-19224-43106                  N                          APPLE INC.
# 3       A-19248-53820                  N                          APPLE INC.
# 4       A-19252-55077                  N                   AON BENFIELD INC.
# ...               ...                ...                                 ...
# 108259  A-21260-45966                  N  KENNEDY INTERNATIONAL SOFTWARE INC
# 108260  A-21263-47053                  N          QUALCOMM TECHNOLOGIES INC.
# 108261  A-21267-49657                  N                         ECO BIO LLC
# 108262  A-21268-49885                  N            Durham Dance Center, Inc
# 108263  A-21270-50634                  N                       ADAEQUARE INC
#
#                   EMPLOYER_ADDRESS_1 EMPLOYER_ADDRESS_2 EMPLOYER_CITY  \
# 0                   5600 NW 72nd AVE                NaN         Miami
# 1                333 W. WACKER DRIVE          SUITE 300       CHICAGO
# 2                 ONE APPLE PARK WAY                NaN     CUPERTINO
# 3                 ONE APPLE PARK WAY                NaN     CUPERTINO
# 4          200 EAST RANDOLPH STREEET                NaN       CHICAGO
# ...                              ...                ...           ...
# 108259  633 E.FERNHURST DR, STE#1302                NaN          KATY
# 108260          5775 MOREHOUSE DRIVE                NaN     SAN DIEGO
# 108261           10506 N Highway 265                NaN  Fayetteville
# 108262               4702 Garrett Rd                NaN        Durham
# 108263             5180 PARKSTONE DR            STE 105     CHANTILLY
#
#        EMPLOYER_STATE_PROVINCE          EMPLOYER_COUNTRY EMPLOYER_POSTAL_CODE  \
# 0                      FLORIDA  UNITED STATES OF AMERICA                33166
# 1                     ILLINOIS  UNITED STATES OF AMERICA                60606
# 2                   CALIFORNIA  UNITED STATES OF AMERICA                95014
# 3                   CALIFORNIA  UNITED STATES OF AMERICA                95014
# 4                     ILLINOIS  UNITED STATES OF AMERICA                60601
# ...                        ...                       ...                  ...
# 108259                   TEXAS  UNITED STATES OF AMERICA                77450
# 108260              CALIFORNIA  UNITED STATES OF AMERICA                92121
# 108261                ARKANSAS  UNITED STATES OF AMERICA                72701
# 108262          NORTH CAROLINA  UNITED STATES OF AMERICA                27707
# 108263                VIRGINIA  UNITED STATES OF AMERICA                20151
#
#         EMPLOYER_PHONE  ... FOREIGN_WORKER_EDUCATION  \
# 0           3053333484  ...               Bachelor's
# 1       (312) 395-5138  ...               Bachelor's
# 2         408-974-4146  ...               Bachelor's
# 3         408-974-4146  ...                Doctorate
# 4         312-381-1000  ...               Bachelor's
# ...                ...  ...                      ...
# 108259    713-568-4545  ...                 Master's
# 108260    858-845-3309  ...                 Master's
# 108261    (479)3689613  ...                    Other
# 108262      9194894313  ...               Bachelor's
# 108263    703-961-0700  ...                 Master's
#
#         FOREIGN_WORKER_EDUCATION_OTHER  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 108259                             NaN
# 108260                             NaN
# 108261                             DVM
# 108262                             NaN
# 108263                             NaN
#
#                                 FOREIGN_WORKER_INFO_MAJOR  \
# 0                                    INDUSTRIAL RELATIONS
# 1               ELECTRONICS AND COMMUNICATION ENGINEERING
# 2                                    COMPUTER ENGINEERING
# 3                                    COMPUTER ENGINEERING
# 4                                             MATHEMATICS
# ...                                                   ...
# 108259                                            SCIENCE
# 108260                ELECTRICAL AND COMPUTER ENGINEERING
# 108261                                VETERINARY MEDICINE
# 108262                              BALLROOM CHOREOGRAPHY
# 108263  COMPUTER APPLICATIONS EQUIVALENT TO A U.S. M.S...
#
#        FOREIGN_WORKER_YRS_ED_COMP  \
# 0                          1999.0
# 1                          2004.0
# 2                          2015.0
# 3                          2017.0
# 4                          2006.0
# ...                           ...
# 108259                     2018.0
# 108260                     2020.0
# 108261                     1993.0
# 108262                     2005.0
# 108263                     2005.0
#
#                               FOREIGN_WORKER_INST_OF_ED  \
# 0                                UNIVERSITY OF CARABOBO
# 1       VISVESWARAIAH TECHNOLOGICAL UNIVERSITY, BELGAUM
# 2                   THE GEORGIA INSTITUTE OF TECHNOLOGY
# 3                                   TEXAS AM UNIVERSITY
# 4                                 UNIVERSITY OF WARWICK
# ...                                                 ...
# 108259                UNIVERSITY OF HOUSTON  CLEAR LAKE
# 108260                UNIVERSITY OF ILLINOIS AT CHICAGO
# 108261          UNIVERSIDAD NACIONAL AUTONOMA DE MEXICO
# 108262                 KHARKIV STATE ACADEMY OF CULTURE
# 108263        JAWAHARLAL NEHRU TECHNOLOGICAL UNIVERSITY
#
#                              FOREIGN_WORKER_ED_INST_ADD_1  \
# 0                                              NAGUANAGUA
# 1                           MSRIT POST, M S RAMAIAH NAGAR
# 2                                            NORTH AVE NW
# 3                                               1226 TAMU
# 4                                                     NaN
# ...                                                   ...
# 108259                            2700 BAY AREA BOULEVARD
# 108260                          1200 WEST HARRISON STREET
# 108261                                  UNIVERSITY CAMPUS
# 108262                              BURSATSKYI DESCENT, 4
# 108263  ASHOK NAGAR, KUKATPALLY HOUSING BOARD COLONY, ...
#
#        FOREIGN_WORKER_ED_INST_ADD_2 FOREIGN_WORKER_ED_INST_CITY  \
# 0                               NaN                    VALENCIA
# 1                               NaN                   BANGALORE
# 2                               NaN                     ATLANTA
# 3                               NaN             COLLEGE STATION
# 4                               NaN                    COVENTRY
# ...                             ...                         ...
# 108259                          NaN                     HOUSTON
# 108260                          NaN                     CHICAGO
# 108261                          NaN                 MEXICO CITY
# 108262                          NaN                     KHARKIV
# 108263                          NaN                   HYDERABAD
#
#        FOREIGN_WORKER_ED_INST_STATE_P FOREIGN_WORKER_ED_INST_COUNTRY
# 0                            CARABOBO                      VENEZUELA
# 1                           KARNATAKA                          INDIA
# 2                                  GA       UNITED STATES OF AMERICA
# 3                                  TX       UNITED STATES OF AMERICA
# 4                                 NaN                 UNITED KINGDOM
# ...                               ...                            ...
# 108259                             TX       UNITED STATES OF AMERICA
# 108260                             IL       UNITED STATES OF AMERICA
# 108261                    MEXICO D.F.                         MEXICO
# 108262                 KHARKIV OBLAST                        UKRAINE
# 108263                      TELANGANA                          INDIA
#
# [108264 rows x 71 columns]

# %%
# companies matched through fuzzy matching on OpenRefine between SEC registered broker-dealers and PERM employers 
matched = pd.read_csv("PERM-Disclosure-Data-FY2021-matched.csv", low_memory=False)
matched_companies = matched['EMPLOYER_NAME'].unique()
matched_companies = matched_companies.tolist()
matched_case_numbers = matched['CASE_NUMBER'].unique()
matched_case_numbers = matched_case_numbers.tolist()

# %%
list(df.columns)
# Out:
# ['CASE_NUMBER',
#  'SCHD_A_SHEEPHERDER',
#  'EMPLOYER_NAME',
#  'EMPLOYER_ADDRESS_1',
#  'EMPLOYER_ADDRESS_2',
#  'EMPLOYER_CITY',
#  'EMPLOYER_STATE_PROVINCE',
#  'EMPLOYER_COUNTRY',
#  'EMPLOYER_POSTAL_CODE',
#  'EMPLOYER_PHONE',
#  'EMPLOYER_PHONE_EXT',
#  'EMPLOYER_NUM_EMPLOYEES',
#  'EMPLOYER_YEAR_COMMENCED_BUSINESS',
#  'PW_TRACK_NUMBER',
#  'PW_SOC_CODE',
#  'PW_SOC_TITLE',
#  'PW_SKILL_LEVEL',
#  'PW_WAGE',
#  'PW_UNIT_OF_PAY',
#  'PW_WAGE_SOURCE',
#  'PW_SOURCE_NAME_OTHER',
#  'PW_DETERMINATION_DATE',
#  'PW_EXPIRATION_DATE',
#  'WAGE_OFFER_FROM',
#  'WAGE_OFFER_TO',
#  'WAGE_OFFER_UNIT_OF_PAY',
#  'WORKSITE_ADDRESS_1',
#  'WORKSITE_ADDRESS_2',
#  'WORKSITE_CITY',
#  'WORKSITE_STATE',
#  'WORKSITE_POSTAL_CODE',
#  'JOB_TITLE',
#  'MINIMUM_EDUCATION',
#  'JOB_EDUCATION_MIN_OTHER',
#  'MAJOR_FIELD_OF_STUDY',
#  'REQUIRED_TRAINING',
#  'REQUIRED_TRAINING_MONTHS',
#  'REQUIRED_FIELD_OF_TRAINING',
#  'REQUIRED_EXPERIENCE',
#  'REQUIRED_EXPERIENCE_MONTHS',
#  'ACCEPT_ALT_FIELD_OF_STUDY',
#  'ACCEPT_ALT_MAJOR_FLD_OF_STUDY',
#  'ACCEPT_ALT_COMBO',
#  'ACCEPT_ALT_COMBO_EDUCATION',
#  'ACCEPT_ALT_COMBO_ED_OTHER',
#  'ACCEPT_ALT_COMBO_EDUCATION_YRS',
#  'ACCEPT_FOREIGN_EDUCATION',
#  'ACCEPT_ALT_OCCUPATION',
#  'ACCEPT_ALT_OCCUPATION_MONTHS',
#  'ACCEPT_ALT_JOB_TITLE',
#  'JOB_OPP_REQUIREMENTS_NORMAL',
#  'FOREIGN_LANGUAGE_REQUIRED',
#  'SPECIFIC_SKILLS',
#  'COMBINATION_OCCUPATION',
#  'OFFERED_TO_APPL_FOREIGN_WORKER',
#  'FOREIGN_WORKER_LIVE_ON_PREM',
#  'PROFESSIONAL_OCCUPATION',
#  'US_WORKERS_CONSIDERED',
#  'COUNTRY_OF_CITIZENSHIP',
#  'FOREIGN_WORKER_BIRTH_COUNTRY',
#  'CLASS_OF_ADMISSION',
#  'FOREIGN_WORKER_EDUCATION',
#  'FOREIGN_WORKER_EDUCATION_OTHER',
#  'FOREIGN_WORKER_INFO_MAJOR',
#  'FOREIGN_WORKER_YRS_ED_COMP',
#  'FOREIGN_WORKER_INST_OF_ED',
#  'FOREIGN_WORKER_ED_INST_ADD_1',
#  'FOREIGN_WORKER_ED_INST_ADD_2',
#  'FOREIGN_WORKER_ED_INST_CITY',
#  'FOREIGN_WORKER_ED_INST_STATE_P',
#  'FOREIGN_WORKER_ED_INST_COUNTRY']

# %%
matched_from_PERM = df[df['CASE_NUMBER'].isin(matched_case_numbers)]
matched_from_PERM_comp = matched_from_PERM['EMPLOYER_NAME'].unique()
matched_from_PERM_comp
# Out:
# array(['CITADEL SECURITIES AMERICAS LLC', 'CITIGROUP GLOBAL MARKETS INC.',
#        'GOLDMAN SACHS  CO. LLC', 'GOLDMAN SACHS SERVICES LLC',
#        'MUFG Securities Americas Inc.',
#        'SUSQUEHANNA INTERNATIONAL GROUP, LLP',
#        'THE PNC FINANCIAL SERVICES GROUP', 'PRICEWATERHOUSECOOPERS',
#        'METLIFE GROUP, INC.', 'UBS SECURITIES LLC',
#        'CREDIT SUISSE SECURITIES USA LLC',
#        'DEUTSCHE BANK SECURITIES, INC.', 'LAZARD FRERES  CO. LLC.',
#        'T. ROWE PRICE ASSOCIATES, INC.', 'TD SECURITIES USA LLC',
#        'Performance Trust Capital Partners, LLC',
#        'MORGAN STANLEY  CO. LLC', 'SCOTIA CAPITAL USA INC',
#        'CITICORP CREDIT SERVICES, INC. USA', 'LIQUIDNET HOLDINGS, INC.',
#        'LLOYDS SECURITIES, INC.', 'JMP SECURITIES LLC',
#        'BOFA SECURITIES, INC.', 'HSBC SECURITIES USA INC.',
#        'SOCIAL FINANCE INC.', 'AKUNA CAPITAL LLC',
#        'CREDIT SUISSE SERVICES USA LLC', 'CITADEL AMERICAS LLC',
#        'WILLIAM BLAIR  COMPANY, LLC', 'RBC Capital Markets LLC',
#        'BRASIL PLURAL SECURITIES LLC', 'ACHELOUS PARTNERS',
#        'BETA CAPITAL SECURITIES, LLC', 'BARCLAYS CAPITAL INC.',
#        'STANCORP FINANCIAL GROUP', 'DWS Distributors, Inc.',
#        'JEFFERIES LLC', 'BULLTICK FINANCIAL SERVICES, LLC',
#        'KEPLER CAPITAL MARKETS, INC.', 'MIZUHO SECURITIES USA LLC',
#        'PACIFIC INVESTMENT MANAGEMENT COMPANY, LLC',
#        'TRADEWEB MARKETS LLC', 'CHARLES SCHWAB  CO., INC.',
#        'BNP Paribas Securities Corp', 'AON SERVICE CORPORATION',
#        'TOWER RESEARCH CAPITAL LLC', 'BARCLAYS SERVICES LLC',
#        'Metric Point Capital, LLC', 'CITIZENS FINANCIAL GROUP, INC.',
#        'NATIONAL SECURITIES CORPORATION', 'LPL FINANCIAL LLC',
#        'CUTLER GROUP, LP', 'Financorp Group International Corporation',
#        'LAZARD ASSET MANAGEMENT LLC', 'Akuna Capital LLC',
#        'SPROTT GLOBAL RESOURCES INVESTMENTS LTD.',
#        'Mariva Capital Markets LLC', 'ING FINANCIAL SERVICES LLC',
#        'MORGAN STANLEY SMITH BARNEY LLC',
#        'NOMURA SECURITIES INTERNATIONAL, INC.', 'PRIMARY CAPITAL, LLC',
#        'GFG Securities, LLC', 'SEI INVESTMENTS COMPANY',
#        'ROBINHOOD MARKETS, INC.', 'Man Investments USA Holdings Inc.',
#        'Mizuho Securities USA LLC',
#        'SANTANDER INVESTMENT SECURITIES, INC.', 'Bain Capital, LP',
#        'FLOW TRADERS US LLC',
#        'NORTHWESTERN MUTUAL INVESTMENT MANAGEMENT COMPANY',
#        'Quiet Light Securities, LLC', 'NATIXIS NORTH AMERICA LLC',
#        'GUGGENHEIM SECURITIES, LLC',
#        'BLACKROCK INVESTMENT MANAGEMENT LLC',
#        'Wells Fargo Clearing Services, LLC',
#        'BNY Mellon Government Securities Services Corp',
#        'BNY Mellon Securities Corporation',
#        'ICBC STANDARD SECURITIES INC.', 'HOULIHAN LOKEY, INC.',
#        'IEX Group, Inc.', 'US TIGER SECURITIES, INC.',
#        'BNP Paribas Financial Services LLC',
#        'ROBERT W. BAIRD  CO. INCORPORATED',
#        'TD AMERITRADE HOLDING CORPORATION',
#        'CohnReznick Capital Markets Securities, LLC',
#        'Fidelity National Management Services, LLC',
#        'MARKETAXESS CORPORATION', 'Brookfield Asset Management LLC',
#        'SG AMERICAS SECURITIES, LLC', 'SEVEN POINTS CAPITAL, LLC',
#        'ALLIANZ GLOBAL INVESTORS US HOLDINGS LLC', 'EXANE, INC.',
#        'ROTHSCHILD  CO US INC.', 'MONEX SECURITIES, INC.',
#        'AXIO FINANCIAL LLC', 'UBS FINANCIAL SERVICES INC.',
#        'LS POWER DEVELOPMENT, LLC', 'Innovation Partners LLC',
#        'Ally Invest', 'ABN AMRO CLEARING CHICAGO LLC',
#        'EFG Capital International Corporation',
#        'Commonwealth Equity Services, LLC', 'Bain  Company, Inc.',
#        'PineBridge Investments LLC', 'CGIS Securities LLC', 'RBC CMA LLC',
#        'DRW HOLDINGS, LLC.', 'JONESTRADING INSTITUTIONAL SERVICES LLC',
#        'SCHRODER INVESTMENT MANAGEMENT N.A. INC.'], dtype=object)

# %%
quant = df[(df['PW_SOC_TITLE'].str.contains("quant", na=False, case=False) | df['JOB_TITLE'].str.contains("quant", na=False, case=False)==True)]
quant = quant[quant['EMPLOYER_NAME'].str.contains('quantitative sciences', na=False, case=False)==False]
quant = quant[quant['EMPLOYER_NAME'].str.contains('university', na=False, case=False)==False]
quant = quant[quant['EMPLOYER_NAME'].str.contains('college', na=False, case=False)==False]
quant = quant[quant['EMPLOYER_NAME'].str.contains('insurance', na=False, case=False)==False]
quant = quant[quant['EMPLOYER_NAME'].str.contains('health', na=False, case=False)==False]
quant_companies = quant['EMPLOYER_NAME'].unique()

# manually clean up some companies that are not finance related at all
remove = np.array(['GARTNER INC.', 'GOOGLE LLC', 'ChainScale Inc', 'INOVALON, INC.', 'FEDERAL HOME LOAN MORTGAGE CORPORATION', 'SEDDIGHEH A FEISEE M.D.', 'MILLENNIUM PHARMACEUTICALS, INC.', 'Oxbow Carbon LLC', 'Adobe Inc.', 'Manufacturers Alliance Foundation dba MAPI Founda', 'YEWNO', 'ATHENE ANNUITY AND LIFE COMPANY', 'FANNIE MAE', 'GROUP H NETWORK LLC', 'ASURION', 'CYGNUS PROFESSIONALS INC', 'CARVANA LLC', '1010DATA SERVICES LLC', 'POSCO AMERICA CORPORATION', 'The Reason Foundation', 'YIPIT, LLC', 'KENPAT CENTRAL FLORIDA LLC', 'TIAA,FSB', 'ORION PROJECT SERVICES', 'MERCK SHARP  DOHME CORP', 'SP Opco LLC', 'AgReliant Genetics, LLC', 'ServiceChannel.com, Inc.', 'CONTEXTLOGIC INC', 'Better Direct LLC', 'IBM CORPORATION', 'ROCHE SEQUENCING SOLUTIONS INC.', 'Strike Technologies, LLC'])
quant_companies = np.setdiff1d(quant_companies, remove, assume_unique=True)
quant_companies
# Out:
# array(['TWO SIGMA INVESTMENTS, LP', 'GOLDMAN SACHS  CO. LLC',
#        'COLUMBIA STATE BANK', 'CAPITAL ONE SERVICES, LLC',
#        'JUMP OPERATIONS', 'MOODYS ANALYTICS', 'MPG OPERATIONS, LLC',
#        'Marshall Wace North America L.P.',
#        'T. ROWE PRICE ASSOCIATES, INC.', 'NANO BANC',
#        'CREDIT SUISSE SECURITIES USA LLC', 'TRUIST BANK',
#        'Bluefin Trading', 'CV ADVISORS LLC',
#        'U.S. BANK NATIONAL ASSOCIATION', 'QUANTCO, INC.',
#        '400 CAPITAL MANAGEMENT LLC', 'D. E. SHAW  CO., L.P.',
#        'JMP SECURITIES LLC', 'BOFA SECURITIES, INC.', 'BANK OF AMERICA',
#        'KEYBANK NATIONAL ASSOCIATION', 'Allston Holdings LLC',
#        'THE PNC FINANCIAL SERVICES GROUP', 'NATIONAL FUTURES ASSOCIATION',
#        'CREDIT SUISSE SERVICES USA LLC', 'BRACEBRIDGE CAPITAL, LLC',
#        'CITADEL AMERICAS LLC', 'Volare Capital Management LLC',
#        'MUFG UNION BANK, N.A.', 'ERNST  YOUNG U.S. LLP',
#        'PACIFIC INVESTMENT MANAGEMENT COMPANY, LLC',
#        'JP MORGAN CHASE  CO', 'GSA CAPITAL PARTNERS NEW YORK LP',
#        'TRANSMARKET OPERATIONS LLC', 'FLAGSTAR BANK, FSB',
#        'STANDARD CHARTERED BANK', 'BLOOMBERG L.P.',
#        'TOWER RESEARCH CAPITAL LLC', 'GEODE CAPITAL MANAGEMENT LLC',
#        'STATE STREET BANK AND TRUST COMPANY',
#        'BAYVIEW ASSET MANAGEMENT, LLC.', 'SOURCE CONSTRUCTION INC.',
#        'GIC Asset Management Pte Ltd', 'ALLIANCEBERNSTEIN L.P.',
#        'VALKYRIE TRADING', 'SCHONFELD STRATEGIC ADVISORS',
#        'OMNIMARKETS, LLC', 'SEVEN EIGHT CAPITAL, LP',
#        'Boothbay Fund Management LLC', 'LINCOLN NATIONAL CORPORATION',
#        'CITIGROUP GLOBAL MARKETS INC.', 'ROYAL BANK OF CANADA',
#        'MIO PARTNERS, INC.', 'WEISS ASSET MANAGEMENT LP',
#        'UBS BUSINESS SOLUTIONS US LLC', 'SQUAREPOINT OPS LLC',
#        'CITADEL SECURITIES AMERICAS LLC',
#        'NATIONAL SECURITIES CORPORATION', 'INTELAGILE LLC',
#        'DRW TEXAS, LLC', 'ATIVO CAPITAL MANAGEMENT LLC', 'MT BANK',
#        'UBS SECURITIES LLC', 'LAZARD ASSET MANAGEMENT LLC',
#        'QS INVESTORS HOLDINGS, LLC', 'Akuna Capital LLC',
#        'NEUBERGER BERMAN GROUP LLC',
#        'ONEMAIN GENERAL SERVICES CORPORATION', 'SUNTRUST BANKS INC',
#        'MCKINLEY CAPITAL MANAGEMENT, LLC', 'OneMarketData LLC',
#        'POINT72 ASSET MANAGEMENT, L.P.', 'SANTANDER CONSUMER USA, INC',
#        'CHICAGO MERCANTILE EXCHANGE', 'SMBC Capital Markets, Inc.',
#        'NOMURA HOLDING AMERICA INC.', 'QMS CAPITAL MANAGEMENT LP',
#        'EXODUSPOINT CAPITAL MANAGEMENT, LP',
#        'NOMURA SECURITIES INTERNATIONAL, INC.',
#        'CHARLES SCHWAB  CO., INC.', 'JANE STREET GROUP, LLC', 'FORT LP',
#        'DYNAMIC HOLDING LLC', 'HSBC TECHNOLOGY  SERVICES USA',
#        'FIRST REPUBLIC BANK', 'BLACKROCK FINANCIAL MANAGEMENT',
#        'TURNER  TOWNSEND, INC.', 'TEZA TECHNOLOGIES LLC',
#        'Man Investments USA Holdings Inc.', 'MARKIT',
#        'HUDSON RIVER TRADING LLC', 'BARCLAYS CAPITAL INC.', 'KPMG LLP',
#        'FMR LLC', 'Cerebellum Capital, Inc.',
#        'SUSQUEHANNA INTERNATIONAL GROUP, LLP', 'CUTLER GROUP, LP',
#        'BOERBOEL LLC', 'BBVA', 'NEW YORK MERCANTILE EXCHANGE, INC.',
#        'GTS Securities, LLC',
#        'Glens Falls National Bank and Trust Company',
#        'Vault Management Inc.', 'TANIUS TECHNOLOGY LLC', 'NUMERIX LLC',
#        'WORLDQUANT, LLC', 'UBS AG,', 'FACTSET RESEARCH SYSTEMS INC.',
#        'LIBERTY MUTUAL GROUP ASSET MANAGEMENT INC.',
#        'WELLS FARGO BANK, N.A.', 'CITIBANK, N.A',
#        'RBC Capital Markets LLC', 'SUNRISE FUTURES, LLC',
#        'GOLDENTREE ASSET MANAGEMENT LP', 'Valley National Bank',
#        'Worldquant Predictive Technologies', 'VIAC SERVICES COMPANY',
#        'XChange Financial Access LLC', 'SANTANDER BANK, N.A.',
#        'CALAMOS ADVISORS LLC', 'CaaS Capital Management LP',
#        'ROBERT W. BAIRD  CO. INCORPORATED', 'PDT PARTNERS, LLC',
#        'INVESCO GROUP SERVICES, INC.',
#        'BLACKROCK INSTITUTIONAL TRUST COMPANY, N.A.',
#        'THE NORTHERN TRUST COMPANY', 'DEUTSCHE BANK',
#        'MORGAN STANLEY SERVICES GROUP INC',
#        'GRANTHAM, MAYO, VAN OTTERLOO  CO. LLC', 'MORGAN STANLEY  CO. LLC',
#        'Regions Bank', 'CUBIST SYSTEMATIC STRATEGIES, LLC',
#        'PENFED CREDIT UNION', 'MORNINGSTAR, INC.',
#        'GOLDMAN SACHS BANK USA', 'NATIXIS NORTH AMERICA LLC',
#        'HSBC BANK USA, N.A.', 'FEDERAL HOME LOAN BANK OF DALLAS',
#        'HSBC SECURITIES USA INC.', 'LORD, ABBETT  CO. LLC',
#        'UBS ASSET MANAGEMENT AMERICAS INC.', 'MERRILL LYNCH',
#        'THE BLACKSTONE GROUP', 'Standard  Poors Financial Services LLC',
#        'Kaleidoscope Capital LP', 'REAL ESTATE EQUITY EXCHANGE INC',
#        'QUANTLAB FINANCIAL, LLC', 'BIOURJA POWER. LLC',
#        'THRIVENT FINANCIAL FOR LUTHERANS', 'ETRADE FINANCIAL CORPORATION',
#        'TD SECURITIES USA LLC', 'MORGAN STANLEY SMITH BARNEY LLC',
#        'TEAM BELVEDERE, LLC', 'VERITION GROUP LLC',
#        'INTERCONTINENTAL EXCHANGE HOLDINGS, INC.',
#        'ELLINGTON MANAGEMENT GROUP, LLC',
#        'GREENSKY ADMINISTRATIVE SERVICES LLC', 'BUTTERFLY EQUITY LP',
#        'SG AMERICAS SECURITIES, LLC', 'Quantbot Technologies LP',
#        'ASCELLA TECHNOLOGIES, INC.', 'BALYASNY ASSET MANAGEMENT L.P.',
#        'BANCO SANTANDER S.A.', 'ALLIANZ GLOBAL INVESTORS US HOLDINGS LLC',
#        'TIOS CAPITAL, LLC', 'RBC CMA LLC', 'ALPHASIMPLEX GROUP, LLC',
#        'AES US SERVICES LLC', 'CITIZENS FINANCIAL GROUP, INC.',
#        'CAPITAL TECHNOLOGY SOLUTIONS, INC.', 'PEAK6 GROUP, LLC',
#        'Lumina Investment Advisors, LLC', 'PGIM, INC.',
#        'CREDIT SUISSE ASSET MANAGEMENT, LLC', 'CENTIVA CAPITAL LP',
#        'BARCLAYS SERVICES CORP', 'SLALOM, LLC',
#        'AMERICAN EXPRESS COMPANY', 'POLARIS7 INVESTMENTS LLC',
#        'WA STATE INVESTMENT BOARD', 'AVANT, LLC',
#        'Wells Capital Management, Inc.',
#        'KING STREET CAPITAL MANAGEMENT, L.P.',
#        'VIRTU FINANCIAL OPERATING LLC', 'LOS ANGELES CAPITAL',
#        'SP Global Market Intelligence, Inc',
#        'SOCIAL MARKET ANALYTICS, INC.', 'NATIONSTAR'], dtype=object)

# %%
trader = df[(df['PW_SOC_TITLE'].str.contains("trader", na=False, case=False) | df['JOB_TITLE'].str.contains("trader", na=False, case=False)==True)]
trader.to_csv('trader.csv')
trader_companies = trader['EMPLOYER_NAME'].unique()
trader_companies

# manually clean up some companies that are not finance related at all
remove = np.array(['BUNGE LATIN AMERICA, LLC', 'Mercuria Energy America, LLC', 'Cooperatieve Rabobank U.A.', 'BAXALTA US INC.', 'LUKOIL Pan Americas, LLC', 'Louis Dreyfus Company LLC', 'RAIZEN NORTH AMERICA, Inc.', 'PAN AMERICAN LIFE INSURANCE COMPANY', 'garcia grain trading corporation', 'Caramax Corporation'])
trader_companies = np.setdiff1d(trader_companies, remove, assume_unique=True)
trader_companies
# Out:
# array(['CITIGROUP GLOBAL MARKETS INC.', 'UBS SECURITIES LLC',
#        'Bluefin Trading', 'OTCex LLC', 'DEUTSCHE BANK',
#        'GOLDMAN SACHS  CO. LLC', 'LIQUIDNET HOLDINGS, INC.',
#        'GALAXY DIGITAL LP', 'Trafigura Trading LLC',
#        'CITADEL AMERICAS LLC', 'CREDIT SUISSE SECURITIES USA LLC',
#        'EAGLES VIEW MANAGEMENT L.P.', 'JP MORGAN CHASE  CO',
#        'TRANSMARKET OPERATIONS LLC', 'VALKYRIE TRADING',
#        'Trexquant Management LLC', 'RONIN CAPITAL, LLC',
#        'RBC Capital Markets LLC', 'BOFA SECURITIES, INC.',
#        'JEFFERIES LLC', 'BNP Paribas Securities Corp',
#        'Akuna Capital LLC', 'Mariva Capital Markets LLC',
#        'WEST COAST FLORIDA ENTERPRISES, INC.', 'NUVEEN SERVICES, LLC',
#        'DYNAMIC HOLDING LLC', 'Goral Trading Company LLC',
#        'JANE STREET GROUP, LLC', 'D. E. SHAW  CO., L.P.',
#        'JUMP OPERATIONS', 'LAURION CAPITAL MANAGEMENT LP',
#        'TOWER RESEARCH CAPITAL LLC', 'ALPHADYNE ASSET MANAGEMENT LLC',
#        'BNP PARIBAS', 'CAMBRIDGE MERCANTILE CORP. USA',
#        'Strategic Global Advisors, LLC', 'CIBC', 'MPG OPERATIONS, LLC',
#        'HSBC BANK USA, N.A.', 'Stifel Financial Corp',
#        'DEUTSCHE BANK SECURITIES, INC.',
#        'BROOKFIELD POWER US ASSET MANAGEMENT LLC',
#        'SEVEN POINTS CAPITAL, LLC', 'CITADEL SECURITIES AMERICAS LLC',
#        'CASTLETON COMMODITIES MANAGEMENT SERVICES, LLC',
#        'NATIXIS NORTH AMERICA LLC', 'SG AMERICAS SECURITIES, LLC',
#        'CITIBANK, N.A', 'MORGAN STANLEY  CO. LLC', 'STONEX GROUP INC.',
#        'PEAK6 GROUP, LLC', 'JMP SECURITIES LLC', 'DRW HOLDINGS, LLC.',
#        'Primex International Trading Corporation',
#        'SCHRODER INVESTMENT MANAGEMENT N.A. INC.'], dtype=object)

# %%
all_companies = np.unique(np.concatenate((matched_from_PERM_comp, quant_companies, trader_companies), axis=None))
all_companies
# Out:
# array(['400 CAPITAL MANAGEMENT LLC', 'ABN AMRO CLEARING CHICAGO LLC',
#        'ACHELOUS PARTNERS', 'AES US SERVICES LLC', 'AKUNA CAPITAL LLC',
#        'ALLIANCEBERNSTEIN L.P.',
#        'ALLIANZ GLOBAL INVESTORS US HOLDINGS LLC',
#        'ALPHADYNE ASSET MANAGEMENT LLC', 'ALPHASIMPLEX GROUP, LLC',
#        'AMERICAN EXPRESS COMPANY', 'AON SERVICE CORPORATION',
#        'ASCELLA TECHNOLOGIES, INC.', 'ATIVO CAPITAL MANAGEMENT LLC',
#        'AVANT, LLC', 'AXIO FINANCIAL LLC', 'Akuna Capital LLC',
#        'Allston Holdings LLC', 'Ally Invest',
#        'BALYASNY ASSET MANAGEMENT L.P.', 'BANCO SANTANDER S.A.',
#        'BANK OF AMERICA', 'BARCLAYS CAPITAL INC.',
#        'BARCLAYS SERVICES CORP', 'BARCLAYS SERVICES LLC',
#        'BAYVIEW ASSET MANAGEMENT, LLC.', 'BBVA',
#        'BETA CAPITAL SECURITIES, LLC', 'BIOURJA POWER. LLC',
#        'BLACKROCK FINANCIAL MANAGEMENT',
#        'BLACKROCK INSTITUTIONAL TRUST COMPANY, N.A.',
#        'BLACKROCK INVESTMENT MANAGEMENT LLC', 'BLOOMBERG L.P.',
#        'BNP PARIBAS', 'BNP Paribas Financial Services LLC',
#        'BNP Paribas Securities Corp',
#        'BNY Mellon Government Securities Services Corp',
#        'BNY Mellon Securities Corporation', 'BOERBOEL LLC',
#        'BOFA SECURITIES, INC.', 'BRACEBRIDGE CAPITAL, LLC',
#        'BRASIL PLURAL SECURITIES LLC',
#        'BROOKFIELD POWER US ASSET MANAGEMENT LLC',
#        'BULLTICK FINANCIAL SERVICES, LLC', 'BUTTERFLY EQUITY LP',
#        'Bain  Company, Inc.', 'Bain Capital, LP', 'Bluefin Trading',
#        'Boothbay Fund Management LLC', 'Brookfield Asset Management LLC',
#        'CALAMOS ADVISORS LLC', 'CAMBRIDGE MERCANTILE CORP. USA',
#        'CAPITAL ONE SERVICES, LLC', 'CAPITAL TECHNOLOGY SOLUTIONS, INC.',
#        'CASTLETON COMMODITIES MANAGEMENT SERVICES, LLC',
#        'CENTIVA CAPITAL LP', 'CGIS Securities LLC',
#        'CHARLES SCHWAB  CO., INC.', 'CHICAGO MERCANTILE EXCHANGE', 'CIBC',
#        'CITADEL AMERICAS LLC', 'CITADEL SECURITIES AMERICAS LLC',
#        'CITIBANK, N.A', 'CITICORP CREDIT SERVICES, INC. USA',
#        'CITIGROUP GLOBAL MARKETS INC.', 'CITIZENS FINANCIAL GROUP, INC.',
#        'COLUMBIA STATE BANK', 'CREDIT SUISSE ASSET MANAGEMENT, LLC',
#        'CREDIT SUISSE SECURITIES USA LLC',
#        'CREDIT SUISSE SERVICES USA LLC',
#        'CUBIST SYSTEMATIC STRATEGIES, LLC', 'CUTLER GROUP, LP',
#        'CV ADVISORS LLC', 'CaaS Capital Management LP',
#        'Cerebellum Capital, Inc.',
#        'CohnReznick Capital Markets Securities, LLC',
#        'Commonwealth Equity Services, LLC', 'D. E. SHAW  CO., L.P.',
#        'DEUTSCHE BANK', 'DEUTSCHE BANK SECURITIES, INC.',
#        'DRW HOLDINGS, LLC.', 'DRW TEXAS, LLC', 'DWS Distributors, Inc.',
#        'DYNAMIC HOLDING LLC', 'EAGLES VIEW MANAGEMENT L.P.',
#        'EFG Capital International Corporation',
#        'ELLINGTON MANAGEMENT GROUP, LLC', 'ERNST  YOUNG U.S. LLP',
#        'ETRADE FINANCIAL CORPORATION', 'EXANE, INC.',
#        'EXODUSPOINT CAPITAL MANAGEMENT, LP',
#        'FACTSET RESEARCH SYSTEMS INC.',
#        'FEDERAL HOME LOAN BANK OF DALLAS', 'FIRST REPUBLIC BANK',
#        'FLAGSTAR BANK, FSB', 'FLOW TRADERS US LLC', 'FMR LLC', 'FORT LP',
#        'Fidelity National Management Services, LLC',
#        'Financorp Group International Corporation', 'GALAXY DIGITAL LP',
#        'GEODE CAPITAL MANAGEMENT LLC', 'GFG Securities, LLC',
#        'GIC Asset Management Pte Ltd', 'GOLDENTREE ASSET MANAGEMENT LP',
#        'GOLDMAN SACHS  CO. LLC', 'GOLDMAN SACHS BANK USA',
#        'GOLDMAN SACHS SERVICES LLC',
#        'GRANTHAM, MAYO, VAN OTTERLOO  CO. LLC',
#        'GREENSKY ADMINISTRATIVE SERVICES LLC',
#        'GSA CAPITAL PARTNERS NEW YORK LP', 'GTS Securities, LLC',
#        'GUGGENHEIM SECURITIES, LLC',
#        'Glens Falls National Bank and Trust Company',
#        'Goral Trading Company LLC', 'HOULIHAN LOKEY, INC.',
#        'HSBC BANK USA, N.A.', 'HSBC SECURITIES USA INC.',
#        'HSBC TECHNOLOGY  SERVICES USA', 'HUDSON RIVER TRADING LLC',
#        'ICBC STANDARD SECURITIES INC.', 'IEX Group, Inc.',
#        'ING FINANCIAL SERVICES LLC', 'INTELAGILE LLC',
#        'INTERCONTINENTAL EXCHANGE HOLDINGS, INC.',
#        'INVESCO GROUP SERVICES, INC.', 'Innovation Partners LLC',
#        'JANE STREET GROUP, LLC', 'JEFFERIES LLC', 'JMP SECURITIES LLC',
#        'JONESTRADING INSTITUTIONAL SERVICES LLC', 'JP MORGAN CHASE  CO',
#        'JUMP OPERATIONS', 'KEPLER CAPITAL MARKETS, INC.',
#        'KEYBANK NATIONAL ASSOCIATION',
#        'KING STREET CAPITAL MANAGEMENT, L.P.', 'KPMG LLP',
#        'Kaleidoscope Capital LP', 'LAURION CAPITAL MANAGEMENT LP',
#        'LAZARD ASSET MANAGEMENT LLC', 'LAZARD FRERES  CO. LLC.',
#        'LIBERTY MUTUAL GROUP ASSET MANAGEMENT INC.',
#        'LINCOLN NATIONAL CORPORATION', 'LIQUIDNET HOLDINGS, INC.',
#        'LLOYDS SECURITIES, INC.', 'LORD, ABBETT  CO. LLC',
#        'LOS ANGELES CAPITAL', 'LPL FINANCIAL LLC',
#        'LS POWER DEVELOPMENT, LLC', 'Lumina Investment Advisors, LLC',
#        'MARKETAXESS CORPORATION', 'MARKIT',
#        'MCKINLEY CAPITAL MANAGEMENT, LLC', 'MERRILL LYNCH',
#        'METLIFE GROUP, INC.', 'MIO PARTNERS, INC.',
#        'MIZUHO SECURITIES USA LLC', 'MONEX SECURITIES, INC.',
#        'MOODYS ANALYTICS', 'MORGAN STANLEY  CO. LLC',
#        'MORGAN STANLEY SERVICES GROUP INC',
#        'MORGAN STANLEY SMITH BARNEY LLC', 'MORNINGSTAR, INC.',
#        'MPG OPERATIONS, LLC', 'MT BANK', 'MUFG Securities Americas Inc.',
#        'MUFG UNION BANK, N.A.', 'Man Investments USA Holdings Inc.',
#        'Mariva Capital Markets LLC', 'Marshall Wace North America L.P.',
#        'Metric Point Capital, LLC', 'Mizuho Securities USA LLC',
#        'NANO BANC', 'NATIONAL FUTURES ASSOCIATION',
#        'NATIONAL SECURITIES CORPORATION', 'NATIONSTAR',
#        'NATIXIS NORTH AMERICA LLC', 'NEUBERGER BERMAN GROUP LLC',
#        'NEW YORK MERCANTILE EXCHANGE, INC.',
#        'NOMURA HOLDING AMERICA INC.',
#        'NOMURA SECURITIES INTERNATIONAL, INC.',
#        'NORTHWESTERN MUTUAL INVESTMENT MANAGEMENT COMPANY', 'NUMERIX LLC',
#        'NUVEEN SERVICES, LLC', 'OMNIMARKETS, LLC',
#        'ONEMAIN GENERAL SERVICES CORPORATION', 'OTCex LLC',
#        'OneMarketData LLC', 'PACIFIC INVESTMENT MANAGEMENT COMPANY, LLC',
#        'PDT PARTNERS, LLC', 'PEAK6 GROUP, LLC', 'PENFED CREDIT UNION',
#        'PGIM, INC.', 'POINT72 ASSET MANAGEMENT, L.P.',
#        'POLARIS7 INVESTMENTS LLC', 'PRICEWATERHOUSECOOPERS',
#        'PRIMARY CAPITAL, LLC', 'Performance Trust Capital Partners, LLC',
#        'PineBridge Investments LLC',
#        'Primex International Trading Corporation',
#        'QMS CAPITAL MANAGEMENT LP', 'QS INVESTORS HOLDINGS, LLC',
#        'QUANTCO, INC.', 'QUANTLAB FINANCIAL, LLC',
#        'Quantbot Technologies LP', 'Quiet Light Securities, LLC',
#        'RBC CMA LLC', 'RBC Capital Markets LLC',
#        'REAL ESTATE EQUITY EXCHANGE INC',
#        'ROBERT W. BAIRD  CO. INCORPORATED', 'ROBINHOOD MARKETS, INC.',
#        'RONIN CAPITAL, LLC', 'ROTHSCHILD  CO US INC.',
#        'ROYAL BANK OF CANADA', 'Regions Bank', 'SANTANDER BANK, N.A.',
#        'SANTANDER CONSUMER USA, INC',
#        'SANTANDER INVESTMENT SECURITIES, INC.',
#        'SCHONFELD STRATEGIC ADVISORS',
#        'SCHRODER INVESTMENT MANAGEMENT N.A. INC.',
#        'SCOTIA CAPITAL USA INC', 'SEI INVESTMENTS COMPANY',
#        'SEVEN EIGHT CAPITAL, LP', 'SEVEN POINTS CAPITAL, LLC',
#        'SG AMERICAS SECURITIES, LLC', 'SLALOM, LLC',
#        'SMBC Capital Markets, Inc.', 'SOCIAL FINANCE INC.',
#        'SOCIAL MARKET ANALYTICS, INC.', 'SOURCE CONSTRUCTION INC.',
#        'SP Global Market Intelligence, Inc',
#        'SPROTT GLOBAL RESOURCES INVESTMENTS LTD.', 'SQUAREPOINT OPS LLC',
#        'STANCORP FINANCIAL GROUP', 'STANDARD CHARTERED BANK',
#        'STATE STREET BANK AND TRUST COMPANY', 'STONEX GROUP INC.',
#        'SUNRISE FUTURES, LLC', 'SUNTRUST BANKS INC',
#        'SUSQUEHANNA INTERNATIONAL GROUP, LLP',
#        'Standard  Poors Financial Services LLC', 'Stifel Financial Corp',
#        'Strategic Global Advisors, LLC', 'T. ROWE PRICE ASSOCIATES, INC.',
#        'TANIUS TECHNOLOGY LLC', 'TD AMERITRADE HOLDING CORPORATION',
#        'TD SECURITIES USA LLC', 'TEAM BELVEDERE, LLC',
#        'TEZA TECHNOLOGIES LLC', 'THE BLACKSTONE GROUP',
#        'THE NORTHERN TRUST COMPANY', 'THE PNC FINANCIAL SERVICES GROUP',
#        'THRIVENT FINANCIAL FOR LUTHERANS', 'TIOS CAPITAL, LLC',
#        'TOWER RESEARCH CAPITAL LLC', 'TRADEWEB MARKETS LLC',
#        'TRANSMARKET OPERATIONS LLC', 'TRUIST BANK',
#        'TURNER  TOWNSEND, INC.', 'TWO SIGMA INVESTMENTS, LP',
#        'Trafigura Trading LLC', 'Trexquant Management LLC',
#        'U.S. BANK NATIONAL ASSOCIATION', 'UBS AG,',
#        'UBS ASSET MANAGEMENT AMERICAS INC.',
#        'UBS BUSINESS SOLUTIONS US LLC', 'UBS FINANCIAL SERVICES INC.',
#        'UBS SECURITIES LLC', 'US TIGER SECURITIES, INC.',
#        'VALKYRIE TRADING', 'VERITION GROUP LLC', 'VIAC SERVICES COMPANY',
#        'VIRTU FINANCIAL OPERATING LLC', 'Valley National Bank',
#        'Vault Management Inc.', 'Volare Capital Management LLC',
#        'WA STATE INVESTMENT BOARD', 'WEISS ASSET MANAGEMENT LP',
#        'WELLS FARGO BANK, N.A.', 'WEST COAST FLORIDA ENTERPRISES, INC.',
#        'WILLIAM BLAIR  COMPANY, LLC', 'WORLDQUANT, LLC',
#        'Wells Capital Management, Inc.',
#        'Wells Fargo Clearing Services, LLC',
#        'Worldquant Predictive Technologies',
#        'XChange Financial Access LLC'], dtype=object)

# %%
def normalize(data):
    res = data.replace(',', '')
    res = res.replace('.', '')
    res = res.upper()
    return res

# %%
def state_to_code(state_name):
    state_name = ''.join([i for i in state_name if not i.isdigit()])
    state = us.states.lookup(state_name)
    if state == None:
        return state_name
    return state.abbr

# %%
df2 = df[['EMPLOYER_NAME',
 'EMPLOYER_ADDRESS_1',
 'EMPLOYER_ADDRESS_2',
 'EMPLOYER_CITY',
 'EMPLOYER_STATE_PROVINCE',
 'EMPLOYER_COUNTRY',
 'EMPLOYER_POSTAL_CODE',]].copy()
df2 = df2.drop_duplicates()
df2 = df2[df2['EMPLOYER_NAME'].isin(all_companies)].reset_index(drop=True)
df2['EMPLOYER_NAME'] = df2['EMPLOYER_NAME'].apply(normalize)
df2['EMPLOYER_ADDRESS_1'] = df2['EMPLOYER_ADDRESS_1'].str.upper()
df2['EMPLOYER_ADDRESS_2'] = df2['EMPLOYER_ADDRESS_2'].str.upper()
df2['EMPLOYER_CITY'] = df2['EMPLOYER_CITY'].str.upper()
df2['EMPLOYER_STATE_PROVINCE'] = df2['EMPLOYER_STATE_PROVINCE'].apply(state_to_code)
df2['EMPLOYER_COUNTRY'] = df2['EMPLOYER_COUNTRY'].str.upper()
df2 = df2.sort_values(by=['EMPLOYER_NAME']).reset_index(drop=True)
df2.index.name = 'COMPANY_ID'
df2.to_csv('companies.csv')
